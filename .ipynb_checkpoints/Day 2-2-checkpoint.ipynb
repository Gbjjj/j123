# %%
train_root  = "C:/Users/pc/Documents/archive/chest_xray/train"
test_root = "C:/Users/pc/Documents/archive/chest_xray/test"
print(train_root)
# Out:
# E:/AI project/Alzheimer_s Dataset/train

# %%
from skimage import io
image = io.imread("E:/AI project/Alzheimer_s Dataset/test/MildDemented/26 (19).jpg")
print(image.shape)
io.imshow(image)

batch_size = 2
# Out:
# (208, 176)

# %%
from keras.preprocessing.image import ImageDataGenerator

Generator = ImageDataGenerator()
train_data = Generator.flow_from_directory(train_root, (150, 150), batch_size=batch_size)
test_data = Generator.flow_from_directory(test_root, (150, 150), batch_size=batch_size)
# Out:
# Found 5121 images belonging to 4 classes.
# Found 1279 images belonging to 4 classes.

# %%
import tensorflow as tf
from matplotlib.pyplot import imshow
import os

im = train_data[0][0][1]
img = tf.keras.preprocessing.image.array_to_img(im)
imshow(img)

num_classes = len([i for i in os.listdir(train_root)])
print(num_classes)
# Out:
# 4

# %%
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D

model = Sequential()

model.add(Conv2D(32, (3, 3), input_shape=(150, 150, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2), strides=2))
model.add(Dropout(0.2))

model.add(Conv2D(32, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2), strides=2))
model.add(Dropout(0.2))

model.add(Conv2D(48, (3, 3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2), strides=2))
model.add(Dropout(0.2))

model.add(Conv2D(48, (4, 4), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2), strides=2))
model.add(Dropout(0.2))

model.add(Flatten())

model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.2))

model.add(Dense(256, activation='relu'))
model.add(Dropout(0.2))

model.add(Dense(num_classes, activation="softmax"))
model.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_36 (Conv2D)          (None, 148, 148, 32)      896
#
#  max_pooling2d_36 (MaxPoolin  (None, 74, 74, 32)       0
#  g2D)
#
#  dropout_54 (Dropout)        (None, 74, 74, 32)        0
#
#  conv2d_37 (Conv2D)          (None, 72, 72, 32)        9248
#
#  max_pooling2d_37 (MaxPoolin  (None, 36, 36, 32)       0
#  g2D)
#
#  dropout_55 (Dropout)        (None, 36, 36, 32)        0
#
#  conv2d_38 (Conv2D)          (None, 34, 34, 48)        13872
#
#  max_pooling2d_38 (MaxPoolin  (None, 17, 17, 48)       0
#  g2D)
#
#  dropout_56 (Dropout)        (None, 17, 17, 48)        0
#
#  conv2d_39 (Conv2D)          (None, 14, 14, 48)        36912
#
#  max_pooling2d_39 (MaxPoolin  (None, 7, 7, 48)         0
#  g2D)
#
#  dropout_57 (Dropout)        (None, 7, 7, 48)          0
#
#  flatten_9 (Flatten)         (None, 2352)              0
#
#  dense_27 (Dense)            (None, 1024)              2409472
#
#  dropout_58 (Dropout)        (None, 1024)              0
#
#  dense_28 (Dense)            (None, 256)               262400
#
#  dropout_59 (Dropout)        (None, 256)               0
#
#  dense_29 (Dense)            (None, 4)                 1028
#
# =================================================================
# Total params: 2,733,828
# Trainable params: 2,733,828
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss=keras.losses.categorical_crossentropy, optimizer=keras.optimizers.Adam(), metrics=['accuracy'])
model.fit(train_data, batch_size = batch_size, epochs=15)
# Out:
# Epoch 1/15
# 2561/2561 [==============================] - 68s 26ms/step - loss: 1.5219 - accuracy: 0.4819
# Epoch 2/15
# 2561/2561 [==============================] - 68s 27ms/step - loss: 1.0480 - accuracy: 0.4950
# Epoch 3/15
# 2561/2561 [==============================] - 68s 26ms/step - loss: 1.0412 - accuracy: 0.4985
# Epoch 4/15
# 2561/2561 [==============================] - 68s 26ms/step - loss: 1.0421 - accuracy: 0.4978
# Epoch 5/15
# 2561/2561 [==============================] - 67s 26ms/step - loss: 1.0409 - accuracy: 0.4997
# Epoch 6/15
# 2561/2561 [==============================] - 67s 26ms/step - loss: 1.0418 - accuracy: 0.4999
# Epoch 7/15
# 2561/2561 [==============================] - 67s 26ms/step - loss: 1.0641 - accuracy: 0.4993
# Epoch 8/15
# 2561/2561 [==============================] - 68s 27ms/step - loss: 1.0413 - accuracy: 0.5009
# Epoch 9/15
# 2561/2561 [==============================] - 71s 28ms/step - loss: 1.0428 - accuracy: 0.4974
# Epoch 10/15
# 2561/2561 [==============================] - 71s 28ms/step - loss: 1.0400 - accuracy: 0.4999
# Epoch 11/15
# 2561/2561 [==============================] - 70s 27ms/step - loss: 1.0396 - accuracy: 0.4999
# Epoch 12/15
# 2561/2561 [==============================] - 69s 27ms/step - loss: 1.0397 - accuracy: 0.4999
# Epoch 13/15
# 2561/2561 [==============================] - 71s 28ms/step - loss: 1.0398 - accuracy: 0.4999
# Epoch 14/15
# 2561/2561 [==============================] - 69s 27ms/step - loss: 1.0391 - accuracy: 0.4999
# Epoch 15/15
# 2561/2561 [==============================] - 69s 27ms/step - loss: 1.0387 - accuracy: 0.4999

# %%
score = model.evaluate(test_data)
print(score)
# Out:
# 640/640 [==============================] - 3s 5ms/step - loss: 1.0347 - accuracy: 0.5004
# [1.034659504890442, 0.5003909468650818]
